# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 五、Pandas数据合并
#
# - pd.concat
# - pd.append
# - pd.merge
#
# 为了方便，我们首先定义一个生成DataFrame的函数：
# ### 1. 使用pd.concat()级联
#
# Pandas使用pd.concat函数，与NumPy中的concatenate函数类似，只是多了一些参数：
#
# #### 1) 简单级联
#
# #### 2) 不匹配级联
#
# 不匹配指的是级联的维度的索引不一致。例如纵向级联时列索引不一致，横向级联时行索引不一致
# - 外连接：补NaN（默认模式）
# - 内连接：只连接匹配的项
#
# ### 2. 使用append()函数添加
#
# 由于在后面级联的使用非常普遍，因此有一个函数append专门用于在后面添加
#
# - 在 Pandas 2.0.0 及以上版本中，DataFrame.append() 方法 已被移除，并标记为弃用。Pandas 推荐使用 pd.concat() 来替代 append() 的功能。
#
# ### 3.使用merge()合并
#
# - 类似MySQL中表和表之间的合并
# - merge与concat的区别在于，merge需要依据某一共同的行或列来进行合并
# - 使用pd.merge()合并时，会自动根据两者相同column名称的那一列，作为key来进行合并。
# - 每一列元素的顺序不要求一致
#
# #### 1) 一对一合并
#
# #### 2) 多对一合并
#
# #### 3) 多对多合并
#
# #### 4) key的规范化
#
# - 使用on=显式指定哪一列为key,当有多个key相同时使用
# - 使用left_on和right_on指定左右两边的列作为key，当左右两边的key都不想等时使用
# - 当左边的列和右边的index相同的时候,使用right_index=True
#
# #### 5) 内合并与外合并
#
# - 内合并：只保留两者都有的key（默认模式）
# - 外合并 how='outer'：补NaN
# - 左合并、右合并：how='left'，how='right'
#
# #### 6) 添加后缀
#
# - 当列冲突时，即有多个列名称相同时，需要使用on=来指定哪一个列作为key，配合suffixes指定冲突列名
# - 可以使用suffixes=自己指定后缀
#
# #### merge合并总结:
#
# - 合并有三种现象: 一对一, 多对一, 多对多.
# - 合并默认会找相同的列名进行合并, 如果有多个列名相同,用on来指定.
# - 如果没有列名相同,但是数据又相同,可以通过left_on, right_on来分别指定要合并的列.
# - 如果想和index合并, 使用left_index, right_index来指定.
# - 如果多个列相同,合并之后可以通过suffixes来区分.
# - 还可以通过how来控制合并的结果, 默认是内合并, 还有外合并outer, 左合并left, 右合并right.

# %% [markdown]
# - pd.concat
# - pd.append
# - pd.merge
#
# 为了方便，我们首先定义一个生成DataFrame的函数：

# %%
def make_df(indexs, columns):    
    data = [[str(j)+str(i) for j in columns] for i in indexs]
    df = pd.DataFrame(data=data, index=indexs, columns=columns)
    return df

# %%
make_df([1, 2, 3, 4], list('ABCD'))
# Out:
#     A   B   C   D
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4

# %% [markdown]
# ### 1. 使用pd.concat()级联
#
# Pandas使用pd.concat函数，与NumPy中的concatenate函数类似，只是多了一些参数：
#
# #### 1) 简单级联
# 参数：
#
# - ignore_index：忽略索引，重置索引
#
# #### 2) 不匹配级联
#
# 不匹配指的是级联的维度的索引不一致。例如纵向级联时列索引不一致，横向级联时行索引不一致

# %%
df1 = make_df([1,2],['A','B'])
df2 = make_df([3,4],['A','B'])
display(df1,df2)
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2
#     A   B
# 3  A3  B3
# 4  A4  B4

# %%
# 默认上下（垂直）合并
pd.concat([df1,df2])
# Out:
#     A   B
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4

# %%
# 左右合并，水平合并，索引不匹配则新增列和行，索引位置不存在值默认为NaN
pd.concat([df1,df2],axis=1)
# Out:
#      A    B    A    B
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3  NaN  NaN   A3   B3
# 4  NaN  NaN   A4   B4

# %% [markdown]
# - ignore_index：忽略索引，重置索引

# %%
display(pd.concat([df1,df2], ignore_index=True))
display(pd.concat([df1,df2], axis=1, ignore_index=True))
# Out:
#     A   B
# 0  A1  B1
# 1  A2  B2
# 2  A3  B3
# 3  A4  B4
#      0    1    2    3
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3  NaN  NaN   A3   B3
# 4  NaN  NaN   A4   B4

# %% [markdown]
# - keys：使用多层索引

# %%
display(pd.concat([df1,df2],keys=['x','y']))
display(pd.concat([df1,df2],axis=1,keys=['x','y']))
# Out:
#       A   B
# x 1  A1  B1
#   2  A2  B2
# y 3  A3  B3
#   4  A4  B4
#      x         y
#      A    B    A    B
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3  NaN  NaN   A3   B3
# 4  NaN  NaN   A4   B4

# %% [markdown]
# #### 2) 不匹配级联
#
# 不匹配指的是级联的维度的索引不一致。例如纵向级联时列索引不一致，横向级联时行索引不一致
#
# - 外连接：补NaN（默认模式）
# - 内连接：只连接匹配的项

# %%
df3 = make_df([1,2,3,4], list('ABCD'))
df4 = make_df([2,3,4,5], list('BCDE'))
display(df3,df4)
# Out:
#     A   B   C   D
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
#     B   C   D   E
# 2  B2  C2  D2  E2
# 3  B3  C3  D3  E3
# 4  B4  C4  D4  E4
# 5  B5  C5  D5  E5

# %%
# 对应索引没有值，自动填充np.NaN
pd.concat([df3,df4])
# Out:
#      A   B   C   D    E
# 1   A1  B1  C1  D1  NaN
# 2   A2  B2  C2  D2  NaN
# 3   A3  B3  C3  D3  NaN
# 4   A4  B4  C4  D4  NaN
# 2  NaN  B2  C2  D2   E2
# 3  NaN  B3  C3  D3   E3
# 4  NaN  B4  C4  D4   E4
# 5  NaN  B5  C5  D5   E5

# %% [markdown]
# - 外连接：补NaN（默认模式）

# %%
# 类似并集的操作，显示所有数据，，如果索引值不存在则补NaN
pd.concat([df3,df4],join='outer')
# Out:
#      A   B   C   D    E
# 1   A1  B1  C1  D1  NaN
# 2   A2  B2  C2  D2  NaN
# 3   A3  B3  C3  D3  NaN
# 4   A4  B4  C4  D4  NaN
# 2  NaN  B2  C2  D2   E2
# 3  NaN  B3  C3  D3   E3
# 4  NaN  B4  C4  D4   E4
# 5  NaN  B5  C5  D5   E5

# %% [markdown]
# - 内连接：只连接匹配的项

# %%
# 类似交集，只显示共同部分
pd.concat([df3,df4],join='inner')
# Out:
#     B   C   D
# 1  B1  C1  D1
# 2  B2  C2  D2
# 3  B3  C3  D3
# 4  B4  C4  D4
# 2  B2  C2  D2
# 3  B3  C3  D3
# 4  B4  C4  D4
# 5  B5  C5  D5

# %% [markdown]
# ### 2. 使用append()函数添加
#
# 由于在后面级联的使用非常普遍，因此有一个函数append专门用于在后面添加
#
# - 在 Pandas 2.0.0 及以上版本中，DataFrame.append() 方法 已被移除，并标记为弃用。Pandas 推荐使用 pd.concat() 来替代 append() 的功能。

# %% [markdown]
# ### 3.使用merge()合并
#
# - 类似MySQL中表和表之间的合并
# - merge与concat的区别在于，merge需要依据某一共同的行或列来进行合并
# - 使用pd.merge()合并时，会自动根据两者相同column名称的那一列，作为key来进行合并。
# - 每一列元素的顺序不要求一致

# %% [markdown]
# #### 1) 一对一合并

# %%
df1 = pd.DataFrame({
    'name':['张三','李四','王五'],
    'id':[1,2,3],
    'age':[22,33,44]
})
df2 = pd.DataFrame({
    'id':[2,3,4],
    'sex':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df1,df2)
# Out:
#   name  id  age
# 0   张三   1   22
# 1   李四   2   33
# 2   王五   3   44
#    id sex        job
# 0   2   男      Saler
# 1   3   女        CEO
# 2   4   男  Programer

# %%
# 合并：相当于数据库的inner join，取两个数组都存在的（相同列）数据
pd.merge(df1,df2),df1.merge(df2)
# Out:
# (  name  id  age sex    job
#  0   李四   2   33   男  Saler
#  1   王五   3   44   女    CEO,
#    name  id  age sex    job
#  0   李四   2   33   男  Saler
#  1   王五   3   44   女    CEO)

# %% [markdown]
# #### 2) 多对一合并

# %%
df3 = pd.DataFrame({
    'name':['张三','李四','王五'],
    'id':[1,2,2],
    'age':[22,33,44]
})
df4 = pd.DataFrame({
    'id':[2,3,4],
    'sex':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df3,df4)
# Out:
#   name  id  age
# 0   张三   1   22
# 1   李四   2   33
# 2   王五   2   44
#    id sex        job
# 0   2   男      Saler
# 1   3   女        CEO
# 2   4   男  Programer

# %%
# 根据相同列匹配
df3.merge(df4)
# Out:
#   name  id  age sex    job
# 0   李四   2   33   男  Saler
# 1   王五   2   44   男  Saler

# %% [markdown]
# #### 3) 多对多合并

# %%
df5 = pd.DataFrame({
    'name':['张三','李四','王五'],
    'id':[1,2,2],
    'age':[22,33,44]
})
df6 = pd.DataFrame({
    'id':[2,2,4],
    'sex':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df5,df6)
# Out:
#   name  id  age
# 0   张三   1   22
# 1   李四   2   33
# 2   王五   2   44
#    id sex        job
# 0   2   男      Saler
# 1   2   女        CEO
# 2   4   男  Programer

# %%
# df5每条数据都会匹配df6的每行数据，如果相同列数据相同，那么会组成一条新的数据
df5.merge(df6)
# Out:
#   name  id  age sex    job
# 0   李四   2   33   男  Saler
# 1   李四   2   33   女    CEO
# 2   王五   2   44   男  Saler
# 3   王五   2   44   女    CEO

# %% [markdown]
# #### 4) key的规范化
#
# - 使用on=显式指定哪一列为key,当有多个key相同时使用
# - 使用left_on和right_on指定左右两边的列作为key，当左右两边的key都不想等时使用
# - 当左边的列和右边的index相同的时候,使用right_index=True

# %% [markdown]
# - 多列相同合并

# %%
df7 = pd.DataFrame({
    'name':['张三','李四','王五'],
    'id':[1,2,2],
    'age':[22,33,44]
})
df8 = pd.DataFrame({
    'id':[2,2,2],
    'name':['张三','李四','王五1'],
    'job':['Saler','CEO','Programer']
})
display(df7,df8)
# Out:
#   name  id  age
# 0   张三   1   22
# 1   李四   2   33
# 2   王五   2   44
#    id name        job
# 0   2   张三      Saler
# 1   2   李四        CEO
# 2   2  王五1  Programer

# %%
# 多列相同合并时，只有相同列数据都一致才算匹配上，然后进行合并
df7.merge(df8)
# Out:
#   name  id  age  job
# 0   李四   2   33  CEO

# %% [markdown]
# - 用on=显式指定哪一列为key,当有多个key相同时使用

# %%
df1 = pd.DataFrame({
    'id':[1,2,3],
    'name':['张三','李四','王五'],
    'age':[22,33,44]
})
df2 = pd.DataFrame({
    'id':[2,3,4],
    'name':['王五','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df1,df2)
# Out:
#    id name  age
# 0   1   张三   22
# 1   2   李四   33
# 2   3   王五   44
#    id name        job
# 0   2   王五      Saler
# 1   3    女        CEO
# 2   4    男  Programer

# %%
# 多列名相同，指定id列为合并列
df1.merge(df2,on='id')
# Out:
#    id name_x  age name_y    job
# 0   2     李四   33     王五  Saler
# 1   3     王五   44      女    CEO

# %%
# 多列名相同，指定id列为合并列
df1.merge(df2,on='name')
# Out:
#    id_x name  age  id_y    job
# 0     3   王五   44     2  Saler

# %% [markdown]
# - 使用left_on和right_on指定左右两边的列作为key，当左右两边的key都不想等时使用

# %%
df1 = pd.DataFrame({
    'id':[1,2,3],
    'name':['张三','李四','王五'],
    'age':[22,33,44]
})
df2 = pd.DataFrame({
    'id2':[2,3,4],
    'sex':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df1,df2)
# Out:
#    id name  age
# 0   1   张三   22
# 1   2   李四   33
# 2   3   王五   44
#    id2 sex        job
# 0    2   男      Saler
# 1    3   女        CEO
# 2    4   男  Programer

# %%
# 没有相同列合并，需要使用left_on和right_on指定左右两边数组的列作为key（指定的列进行合并）
df1.merge(df2, left_on='id', right_on='id2')
# Out:
#    id name  age  id2 sex    job
# 0   2   李四   33    2   男  Saler
# 1   3   王五   44    3   女    CEO

# %% [markdown]
# - 当左边的列和右边的index相同的时候,使用right_index=True

# %%
df1 = pd.DataFrame({
    'id':[1,2,3],
    'name':['张三','李四','王五'],
    'age':[22,33,44]
})
df2 = pd.DataFrame({
    'id2':[2,3,4],
    'sex':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df1,df2)
# Out:
#    id name  age
# 0   1   张三   22
# 1   2   李四   33
# 2   3   王五   44
#    id2 sex        job
# 0    2   男      Saler
# 1    3   女        CEO
# 2    4   男  Programer

# %%
# 使用隐式索引进行合并，相同的隐式索引进行合并
df1.merge(df2,left_index=True,right_index=True)
# 使用第一个数组的隐式索引与第二个索引的某列进行合并
df1.merge(df2,left_index=True,right_on='id2')
# Out:
#    id name  age  id2 sex    job
# 0   3   王五   44    2   男  Saler

# %% [markdown]
# #### 5) 内合并与外合并
#
# - 内合并：只保留两者都有的key（默认模式）-- 类似 inner join
# - 外合并 how='outer'：补NaN -- 类似 Outer Join
# - 左合并、右合并：how='left'，how='right' -- 类似 left join / right join

# %%
df1 = pd.DataFrame({
    'id':[1,2,3],
    'name':['张三','李四','王五'],
    'age':[22,33,44]
})
df2 = pd.DataFrame({
    'id':[2,3,4],
    'sex':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df1,df2)
# Out:
#    id name  age
# 0   1   张三   22
# 1   2   李四   33
# 2   3   王五   44
#    id sex        job
# 0   2   男      Saler
# 1   3   女        CEO
# 2   4   男  Programer

# %%
# 内连接：默认模式
df1.merge(df2), df1.merge(df2, how='inner')
# Out:
# (   id name  age sex    job
#  0   2   李四   33   男  Saler
#  1   3   王五   44   女    CEO,
#     id name  age sex    job
#  0   2   李四   33   男  Saler
#  1   3   王五   44   女    CEO)

# %%
# 外连接：取所有数据并集，如果不匹配则补NaN
df1.merge(df2, how='outer')
# Out:
#    id name   age  sex        job
# 0   1   张三  22.0  NaN        NaN
# 1   2   李四  33.0    男      Saler
# 2   3   王五  44.0    女        CEO
# 3   4  NaN   NaN    男  Programer

# %%
# 左合并：取左边表的所有数据，匹配右边表的数据，如果没有匹配上则补NaN
df1.merge(df2, how='left')
# Out:
#    id name  age  sex    job
# 0   1   张三   22  NaN    NaN
# 1   2   李四   33    男  Saler
# 2   3   王五   44    女    CEO

# %%
df1 = pd.DataFrame({
    'id':[1,2,3],
    'name':['张三','李四','王五'],
    'age':[22,33,44]
})
df2 = pd.DataFrame({
    'id':[2,3,4],
    'sex':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df1,df2)

# %%
# 右合并：取右边表的所有数据，匹配左边表的数据，如果没有匹配上则补NaN
df1.merge(df2, how='right')
# Out:
#    id name   age sex        job
# 0   2   李四  33.0   男      Saler
# 1   3   王五  44.0   女        CEO
# 2   4  NaN   NaN   男  Programer

# %% [markdown]
# #### 6) 添加后缀
#
# - 当列冲突时，即有多个列名称相同时，需要使用on=来指定哪一个列作为key，配合suffixes指定冲突列名
# - 可以使用suffixes=自己指定后缀

# %%
df1 = pd.DataFrame({
    'id':[1,2,3],
    'name':['张三','李四','王五'],
    'age':[22,33,44]
})
df2 = pd.DataFrame({
    'id':[2,3,4],
    'name':['男','女','男'],
    'job':['Saler','CEO','Programer']
})
display(df1,df2)
# Out:
#    id name  age
# 0   1   张三   22
# 1   2   李四   33
# 2   3   王五   44
#    id name        job
# 0   2    男      Saler
# 1   3    女        CEO
# 2   4    男  Programer

# %%
df1.merge(df2, on='id',suffixes=['_df1','_df2'])
# Out:
#    id name_df1  age name_df2    job
# 0   2       李四   33        男  Saler
# 1   3       王五   44        女    CEO

# %% [markdown]
# #### merge合并总结:
#
# - 合并有三种现象: 一对一, 多对一, 多对多.
# - 合并默认会找相同的列名进行合并, 如果有多个列名相同,用on来指定.
# - 如果没有列名相同,但是数据又相同,可以通过left_on, right_on来分别指定要合并的列.
# - 如果想和index合并, 使用left_index, right_index来指定.
# - 如果多个列相同,合并之后可以通过suffixes来区分.
# - 还可以通过how来控制合并的结果, 默认是内合并, 还有外合并outer, 左合并left, 右合并right.
